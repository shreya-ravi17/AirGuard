# %%
import pandas as pd

df = pd.read_csv('../data/city_day.csv')
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (29531, 16)
# ['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket']
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB
# City              0
# Date              0
# ...

# %%
columns_needed = ['City', 'Date', 'CO', 'NH3', 'Benzene', 'NOx', 'AQI', 'AQI_Bucket']
df_clean = df[columns_needed].copy()

df_clean = df_clean.dropna(subset=['CO', 'NH3', 'Benzene', 'NOx', 'AQI', 'AQI_Bucket'])

print(df_clean.shape)
df_clean.isnull().sum()
# Out:
# (15268, 8)
# City          0
# Date          0
# CO            0
# NH3           0
# Benzene       0
# NOx           0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
correlation = df_clean[['CO', 'NH3', 'Benzene', 'NOx', 'AQI']].corr()
print(correlation['AQI'])
# Out:
# CO         0.301308
# NH3        0.280275
# Benzene    0.013158
# NOx        0.605922
# AQI        1.000000
# Name: AQI, dtype: float64

# %%
features = ['CO', 'NH3', 'NOx']
target_category = 'AQI_Bucket'
target_value = 'AQI'

# %%
columns_needed = ['City', 'Date', 'CO', 'NH3', 'NOx', 'AQI', 'AQI_Bucket']
df_clean = df[columns_needed].copy()
df_clean = df_clean.dropna(subset=['CO', 'NH3', 'NOx', 'AQI', 'AQI_Bucket'])

print(df_clean.shape)
df_clean.to_csv('../data/cleaned_data.csv', index=False)
# Out:
# (17183, 7)

# %%
df_check = df[['CO', 'NH3', 'NOx', 'NO2', 'AQI']].dropna()
correlation = df_check.corr()
print(correlation['AQI'])
# Out:
# CO     0.289262
# NH3    0.273012
# NOx    0.600723
# NO2    0.603803
# AQI    1.000000
# Name: AQI, dtype: float64

# %%
print(df_check[['NOx', 'NO2']].corr())
# Out:
#           NOx       NO2
# NOx  1.000000  0.661287
# NO2  0.661287  1.000000

# %%
features = ['CO', 'NH3', 'NO2']
target = 'AQI'  # for regression, or use AQI_Bucket for classification

# %%
columns_needed = ['City', 'Date', 'CO', 'NH3', 'NO2', 'AQI', 'AQI_Bucket']
df_clean = df[columns_needed].copy()
df_clean = df_clean.dropna(subset=['CO', 'NH3', 'NO2', 'AQI', 'AQI_Bucket'])

print(df_clean.shape)
df_clean.to_csv('../data/cleaned_data.csv', index=False)
# Out:
# (17845, 7)
